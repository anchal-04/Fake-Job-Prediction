# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
fake_postings = pd.read_csv('../data/fake_job_postings.csv')
fake_postings
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
# Get jobs posted only in US
fake_postings.location = fake_postings.location.fillna('blank')
fake_postings_US = fake_postings[fake_postings['location'].str.contains("US")]
fake_postings_US
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# 5           6                                   Accounting Clerk
# ...       ...                                                ...
# 17872   17873                                    Product Manager
# 17873   17874                             Recruiting Coordinator
# 17874   17875                               JavaScript Developer
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
#
#                     location           department  salary_range  \
# 0           US, NY, New York            Marketing           NaN
# ...

# %%
location =[]
for loc in fake_postings_US.location:
    location.append(loc.split(','))

location = pd.DataFrame(location)

location = location[[1, 2]]

location = location.rename(columns={1: "State", 2:'City'})

# %%
fake_postings_US = fake_postings_US.reset_index()
fake_postings_US = fake_postings_US.join(location)

# %%
fake_postings_US = fake_postings_US[['job_id', 'title', 'location', 'department', 'salary_range',
       'company_profile', 'description', 'requirements', 'benefits',
       'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
       'required_experience', 'required_education', 'industry', 'function',
       'fraudulent', 'State', 'City']]

# %%
fake_postings_US = fake_postings_US[fake_postings_US['City'].notna()]
fake_postings_US = fake_postings_US[fake_postings_US['State'].notna()]

# %%
fake_postings_US.shape
# Out:
# (10593, 20)

# %%
fake_postings_US['State_City'] = fake_postings_US['State'] + ", " + fake_postings_US['City']

# %%
fake_postings_US.City = fake_postings_US.City.str.strip()
fake_postings_US.State = fake_postings_US.State.str.strip()

# %%
fake_postings_US
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           3            Commissioning Machinery Assistant (CMA)
# 2           4                  Account Executive - Washington DC
# 3           5                                Bill Review Manager
# 4           6                                   Accounting Clerk
# ...       ...                                                ...
# 10651   17873                                    Product Manager
# 10652   17874                             Recruiting Coordinator
# 10653   17875                               JavaScript Developer
# 10654   17877                                 Payroll Accountant
# 10655   17878  Project Cost Control Staff Engineer - Cost Con...
#
#                     location           department  salary_range  \
# 0           US, NY, New York            Marketing           NaN
# ...

# %%
# correlation_matrix = fake_postings_US.corr()
# sns.heatmap(correlation_matrix)
# plt.show()

# %%
len(fake_postings_US[fake_postings_US.fraudulent == 0]), len(fake_postings_US[fake_postings_US.fraudulent == 1]),
# Out:
# (9868, 725)

# %%
fraudulent_counts = fake_postings_US['fraudulent'].value_counts()
plt.pie(fraudulent_counts, labels=fraudulent_counts.index, autopct='%1.1f%%')
plt.title('Fraudulent Postings Count')
plt.axis('equal')
plt.show()

# %%
def sns_countplot(feature):
    sns.countplot(x=feature, data=fake_postings_US, hue="fraudulent",
              order=fake_postings_US[feature].value_counts().iloc[:10].index)
    plt.xticks(rotation=90)
    title = feature + ' fake job count'
    plt.title('Location Fake Jobs')
    plt.show()

# %%
plt.figure(figsize=(10,6))
fake_postings_US.groupby('Splt.figure(figsize=(10,6))
sns.countplot(x='state', data=fake_job_postings_US, hue="fraudulent", order=fake_job_postings_US['state'].value_counts().iloc[:10].index)
plt.xticks(rotation=90)
plt.show()tate').fraudulent.count().plot(kind='bar', title='Job count by states');

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='State', data=fake_postings_US, hue="fraudulent", order=fake_postings_US['State'].value_counts().iloc[:10].index)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='State_City', data=fake_postings_US, hue="fraudulent", order=fake_postings_US['State_City'].value_counts().iloc[:10].index)
plt.xticks(rotation=90)
plt.show()

# %%
def sns_countplot(feature):
    sns.countplot(x=feature, data=fake_postings_US, hue="fraudulent",
              order=fake_postings_US[feature].value_counts().iloc[:10].index)
    plt.xticks(rotation=90)
    title = feature + ' fake job count'
    plt.title(title)
    plt.show()

# %%
sns_countplot('employment_type');

# %%
sns_countplot('required_experience');

# %%
sns_countplot('required_education');

# %%
location_ratio = round(fake_postings_US[fake_postings_US.fraudulent == 1].groupby('State_City').State_City.count()/fake_postings_US[fake_postings_US.fraudulent == 0].groupby('State_City').State_City.count(), 2)
location_ratio = pd.DataFrame({'State_City':location_ratio.index, 'ratio':location_ratio.values})

# %%
fake_postings_US = fake_postings_US.merge(location_ratio)

# %%
fake_postings_US.ratio.fillna(0, inplace=True)
# Out:
# /var/folders/lv/zyn4npcs71d8q7rcgfskc0d40000gn/T/ipykernel_5682/951507830.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fake_postings_US.ratio.fillna(0, inplace=True)

# %%
location_ratio_plot = location_ratio[location_ratio.ratio >= 1]

# %%
sns.barplot(data=location_ratio_plot.sort_values(by='ratio'), x='State_City', y='ratio')
plt.xticks(rotation=90)
plt.title('Fake to Real Job Ratio')
plt.show()

# %%
def missing_count(feature, title='None'):
    y_axis = fake_postings_US[fake_postings_US[feature].isna()][['fraudulent', feature]]
    y_axis = y_axis.fraudulent.value_counts()
    y_axis.plot(kind='bar')
    plt.ylabel('Count')
    plt.xlabel('Category')
    title = "Number of empty " + title + " in fraudulent and non-fraudulent"
    plt.title(title)
    plt.xticks(rotation=0)
    plt.show()
    return 0

# %%
missing_count('function', 'Functions')
# Out:
# 0

# %%
missing_count('company_profile', 'Company Profile')
# Out:
# 0

# %%
missing_count('required_education', 'required_education')
# Out:
# 0

# %%
missing_count('industry', 'Industry')
# Out:
# 0

# %%
missing_count('benefits', 'Benefits')
# Out:
# 0

# %%
telecommuting_list = []
has_company_logo_list = []

for idx, tel, logo in zip(range(len(fake_postings_US)), fake_postings_US.telecommuting, fake_postings_US.has_company_logo):
    if fake_postings.fraudulent[idx] == 1:
        telecommuting_list.append(tel)
        has_company_logo_list.append(logo)
    else:
        pass

telecommuting_logo_df = pd.DataFrame({'telecommuting':telecommuting_list, 'has_company_logo':has_company_logo_list})

# %%
fake_count = 0

for fraud, tel, logo in zip(fake_postings_US.fraudulent, fake_postings_US.telecommuting, fake_postings_US.has_company_logo):
    if (tel == 0 and logo == 0):
        if (fraud == 1):
            fake_count +=1
        else:
            pass
    else:
        pass


print(fake_count)
# Out:
# 425

# %%
fake_count = 0

for fraud, tel, logo, ques in zip(fake_postings_US.fraudulent, fake_postings_US.telecommuting, fake_postings_US.has_company_logo, fake_postings_US.has_questions):
    if (tel == 0):# and logo == 0 and ques == 0):
        if (fraud == 1):
            fake_count +=1
        else:
            pass
    else:
        pass


print(fake_count)
# Out:
# 667

# %%
len(fake_postings_US[fake_postings_US.fraudulent == 1])
# Out:
# 725

# %%
667/725
# Out:
# 0.92

# %%
fake_count/len(fake_postings_US[fake_postings_US.fraudulent == 1]) * 100
# Out:
# 92.0

# %%
fake_postings_US.fillna(" ",inplace = True)

fake_postings_US['text'] =  fake_postings_US['title'] + ' ' + fake_postings_US['location'] + ' ' + fake_postings_US['company_profile'] + ' ' + \
        fake_postings_US['description'] + ' ' + fake_postings_US['requirements'] + ' ' + fake_postings_US['benefits'] + ' ' + \
        fake_postings_US['required_experience'] + ' ' + fake_postings_US['required_education'] + ' ' + fake_postings_US['industry'] + ' ' + fake_postings_US['function']


fake_postings_US.drop(['job_id', 'department', 'salary_range', 'title','location','department','company_profile','description','requirements','benefits','employment_type','required_experience','required_education','industry','function', 'City', 'State_City', 'has_company_logo', 'has_questions', 'State'], axis = 1, inplace = True)

# %%
fake_postings_US
# Out:
#        telecommuting  fraudulent  ratio  \
# 0                  0           0   0.03
# 1                  0           0   0.00
# 2                  0           0   0.01
# 3                  0           0   0.00
# 4                  0           0   1.00
# ...              ...         ...    ...
# 10588              0           0   0.02
# 10589              0           0   0.03
# 10590              0           0   0.09
# 10591              0           0   0.05
# 10592              0           0   0.52
#
#                                                     text
# 0      Marketing Intern US, NY, New York We're Food52...
# 1      Commissioning Machinery Assistant (CMA) US, IA...
# 2      Account Executive - Washington DC US, DC, Wash...
# 3      Bill Review Manager US, FL, Fort Worth SpotSou...
# 4      Accounting Clerk US, MD,    Job OverviewApex i...
# ...                                                  ...
# 10588  Product Manager US, CA, San Francisco Flite de...
# ...

# %%
fake_postings_US['character_count'] = fake_postings_US.text.apply(len)

fake_postings_US[fake_postings_US.fraudulent==0].character_count.plot(bins=35, kind='hist', color='blue', 
                                       label='Real', alpha=0.8)
fake_postings_US[fake_postings_US.fraudulent==1].character_count.plot(kind='hist', color='red', 
                                       label='Fake', alpha=0.8)
plt.legend()
plt.title('Frequency of Words')
plt.xlabel("Character Count");

# %%
fake_postings_US
# Out:
#        telecommuting  fraudulent  ratio  \
# 0                  0           0   0.03
# 1                  0           0   0.00
# 2                  0           0   0.01
# 3                  0           0   0.00
# 4                  0           0   1.00
# ...              ...         ...    ...
# 10588              0           0   0.02
# 10589              0           0   0.03
# 10590              0           0   0.09
# 10591              0           0   0.05
# 10592              0           0   0.52
#
#                                                     text  character_count
# 0      Marketing Intern US, NY, New York We're Food52...             2705
# 1      Commissioning Machinery Assistant (CMA) US, IA...             2663
# 2      Account Executive - Washington DC US, DC, Wash...             5540
# 3      Bill Review Manager US, FL, Fort Worth SpotSou...             4047
# 4      Accounting Clerk US, MD,    Job OverviewApex i...             3458
# ...

# %% [markdown]
# ** Text Analysis**

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anchalsingh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/anchalsingh/nltk_data...

# %%
text = fake_postings_US.text.to_list()
text = ' '.join(text)
tokens_text = word_tokenize(text)

# %%
lower_tokens = [t.lower() for t in tokens_text]
word_freq = Counter(lower_tokens)
print(Counter.most_common(word_freq, 10))
# Out:
# [(',', 248538), ('and', 217658), ('to', 122845), ('the', 109318), ('.', 105032), ('of', 86305), ('a', 79631), ('in', 69807), ('with', 52173), ('for', 49748)]

# %%
text_only_alphabets = [t for t in lower_tokens if t.isalpha()]

# %%
english_stopped = stopwords.words('english')
no_stops = [t for t in text_only_alphabets if t not in english_stopped]

# %%
wordnet_lemmatizer = WordNetLemmatizer()

lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]
bow = Counter(lemmatized)
print(Counter.most_common(bow, 10))
# Out:
# [('service', 22304), ('experience', 22284), ('work', 20787), ('customer', 19040), ('team', 18650), ('company', 17226), ('u', 17062), ('business', 13857), ('client', 13009), ('sale', 11779)]

# %%
fake_postings_US.to_csv('../data/fake_postings_cleaned.csv')

# %%
fake_postings_US.shape
# Out:
# (10593, 5)
